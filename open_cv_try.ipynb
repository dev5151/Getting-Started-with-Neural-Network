# %%
import cv2
from google.colab import files
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4a220342-4e42-4cf0-b3af-deede4d298f6" name="files[]" multiple disabled />
#      <output id="result-4a220342-4e42-4cf0-b3af-deede4d298f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.jpg to download.jpg

# %%
image=cv2.imread('download.jpg',cv2.IMREAD_UNCHANGED)

# %%
image
# Out:
# array([[[ 24, 128, 121],
#         [ 25, 129, 122],
#         [ 27, 130, 123],
#         ...,
#         [136, 224, 231],
#         [136, 224, 231],
#         [136, 224, 231]],
#
#        [[ 23, 127, 120],
#         [ 24, 128, 121],
#         [ 27, 130, 123],
#         ...,
#         [134, 222, 229],
#         [134, 222, 229],
#         [134, 222, 229]],
#
#        [[ 22, 126, 119],
#         [ 24, 128, 121],
#         [ 27, 130, 123],
#         ...,
#         [130, 218, 225],
#         [130, 218, 225],
#         [130, 218, 225]],
#
#        ...,
#
#        [[ 68, 129,  95],
#         [ 67, 131,  96],
#         [ 69, 133,  98],
#         ...,
#         [ 22, 112,  83],
#         [ 22, 112,  83],
#         [ 22, 112,  83]],
#
#        [[ 72, 130,  95],
#         [ 73, 131,  96],
#         [ 73, 134,  98],
#         ...,
#         [ 22, 112,  83],
#         [ 22, 112,  83],
#         [ 22, 112,  83]],
#
#        [[ 74, 131,  93],
#         [ 73, 132,  94],
#         [ 72, 133,  95],
#         ...,
#         [ 21, 111,  82],
#         [ 21, 111,  82],
#         [ 22, 112,  83]]], dtype=uint8)

# %%
image.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(image)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
plt.imshow(image[:,:,2])

# %%
test_image=cv2.imread('download.jpg',0)
plt.imshow(test_image,cmap="gray")
